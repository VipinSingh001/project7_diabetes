# %%
import pandas as pd
import numpy as np 
import seaborn as sns
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn import linear_model
import warnings
warnings.filterwarnings('ignore')

# %%
#sns.get_dataset_names()
df=datasets.load_diabetes()
dir(df)
# Out:
# ['DESCR',
#  'data',
#  'data_filename',
#  'feature_names',
#  'target',
#  'target_filename']

# %%
df.feature_names
# Out:
# ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']

# %%
#seprate input and output
df_input=pd.DataFrame(df.data,columns=df.feature_names)
df_output=pd.DataFrame(df.target,columns=['DiseaseProgression'])

# %%
df_input   #all values are in scaled format already
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 0    0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1   -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2    0.085299  0.050680  0.044451 -0.005671 -0.045599 -0.034194 -0.032356
# 3   -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4    0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
# ..        ...       ...       ...       ...       ...       ...       ...
# 437  0.041708  0.050680  0.019662  0.059744 -0.005697 -0.002566 -0.028674
# 438 -0.005515  0.050680 -0.015906 -0.067642  0.049341  0.079165 -0.028674
# 439  0.041708  0.050680 -0.015906  0.017282 -0.037344 -0.013840 -0.024993
# 440 -0.045472 -0.044642  0.039062  0.001215  0.016318  0.015283 -0.028674
# 441 -0.045472 -0.044642 -0.073030 -0.081414  0.083740  0.027809  0.173816
#
#            s4        s5        s6
# 0   -0.002592  0.019908 -0.017646
# 1   -0.039493 -0.068330 -0.092204
# 2   -0.002592  0.002864 -0.025930
# 3    0.034309  0.022692 -0.009362
# 4   -0.002592 -0.031991 -0.046641
# ..        ...       ...       ...
# 437 -0.002592  0.031193  0.007207
# 438  0.034309 -0.018118  0.044485
# 439 -0.011080 -0.046879  0.015491
# 440  0.026560  0.044528 -0.025930
# 441 -0.039493 -0.004220  0.003064
#
# [442 rows x 10 columns]

# %%
df_output
# Out:
#      DiseaseProgression
# 0                 151.0
# 1                  75.0
# 2                 141.0
# 3                 206.0
# 4                 135.0
# ..                  ...
# 437               178.0
# 438               104.0
# 439               132.0
# 440               220.0
# 441                57.0
#
# [442 rows x 1 columns]

# %%
#lets check whether it contains any null values or not
df_input.isnull().sum()
#no null value present in input
# Out:
# age    0
# sex    0
# bmi    0
# bp     0
# s1     0
# s2     0
# s3     0
# s4     0
# s5     0
# s6     0
# dtype: int64

# %%
df_output.isnull().sum()   # no null value present in output
# Out:
# DiseaseProgression    0
# dtype: int64

# %%
#lets check the correlation matrix
pd.concat([df_input,df_output],axis=1).corr()
# most of features have week correlation with target only some are around 0.5
# Out:
#                          age       sex       bmi        bp        s1  \
# age                 1.000000  0.173737  0.185085  0.335427  0.260061
# sex                 0.173737  1.000000  0.088161  0.241013  0.035277
# bmi                 0.185085  0.088161  1.000000  0.395415  0.249777
# bp                  0.335427  0.241013  0.395415  1.000000  0.242470
# s1                  0.260061  0.035277  0.249777  0.242470  1.000000
# s2                  0.219243  0.142637  0.261170  0.185558  0.896663
# s3                 -0.075181 -0.379090 -0.366811 -0.178761  0.051519
# s4                  0.203841  0.332115  0.413807  0.257653  0.542207
# s5                  0.270777  0.149918  0.446159  0.393478  0.515501
# s6                  0.301731  0.208133  0.388680  0.390429  0.325717
# DiseaseProgression  0.187889  0.043062  0.586450  0.441484  0.212022
#
#                           s2        s3        s4        s5        s6  \
# age                 0.219243 -0.075181  0.203841  0.270777  0.301731
# sex                 0.142637 -0.379090  0.332115  0.149918  0.208133
# bmi                 0.261170 -0.366811  0.413807  0.446159  0.388680
# bp                  0.185558 -0.178761  0.257653  0.393478  0.390429
# s1                  0.896663  0.051519  0.542207  0.515501  0.325717
# s2                  1.000000 -0.196455  0.659817  0.318353  0.290600
# s3                 -0.196455  1.000000 -0.738493 -0.398577 -0.273697
# s4                  0.659817 -0.738493  1.000000  0.617857  0.417212
# s5                  0.318353 -0.398577  0.617857  1.000000  0.464670
# s6                  0.290600 -0.273697  0.417212  0.464670  1.000000
# DiseaseProgression  0.174054 -0.394789  0.430453  0.565883  0.382483
#
#                     DiseaseProgression
# age                           0.187889
# sex                           0.043062
# bmi                           0.586450
# bp                            0.441484
# s1                            0.212022
# s2                            0.174054
# s3                           -0.394789
# s4                            0.430453
# s5                            0.565883
# s6                            0.382483
# DiseaseProgression            1.000000

# %%
# lets describe the dataset
pd.concat([df_input,df_output],axis=1).describe()
# scaled data
# Out:
#                 age           sex           bmi            bp            s1  \
# count  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02
# mean  -3.634285e-16  1.308343e-16 -8.045349e-16  1.281655e-16 -8.835316e-17
# std    4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02
# min   -1.072256e-01 -4.464164e-02 -9.027530e-02 -1.123996e-01 -1.267807e-01
# 25%   -3.729927e-02 -4.464164e-02 -3.422907e-02 -3.665645e-02 -3.424784e-02
# 50%    5.383060e-03 -4.464164e-02 -7.283766e-03 -5.670611e-03 -4.320866e-03
# 75%    3.807591e-02  5.068012e-02  3.124802e-02  3.564384e-02  2.835801e-02
# max    1.107267e-01  5.068012e-02  1.705552e-01  1.320442e-01  1.539137e-01
#
#                  s2            s3            s4            s5            s6  \
# count  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02
# mean   1.327024e-16 -4.574646e-16  3.777301e-16 -3.830854e-16 -3.412882e-16
# std    4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02
# min   -1.156131e-01 -1.023071e-01 -7.639450e-02 -1.260974e-01 -1.377672e-01
# 25%   -3.035840e-02 -3.511716e-02 -3.949338e-02 -3.324879e-02 -3.317903e-02
# 50%   -3.819065e-03 -6.584468e-03 -2.592262e-03 -1.947634e-03 -1.077698e-03
# 75%    2.984439e-02  2.931150e-02  3.430886e-02  3.243323e-02  2.791705e-02
# max    1.987880e-01  1.811791e-01  1.852344e-01  1.335990e-01  1.356118e-01
#
#        DiseaseProgression
# count          442.000000
# mean           152.133484
# std             77.093005
# min             25.000000
# 25%             87.000000
# 50%            140.500000
# 75%            211.500000
# max            346.000000

# %%
# lets check outlier using z score
from scipy.stats import zscore
df_combined=pd.concat([df_input,df_output],axis=1)
print(df_combined.shape)
z_scr=zscore(df_combined)
df_combined_new=df_combined.loc[(abs(z_scr)<3).all(axis=1)]
print(df_combined_new.shape)
# Out:
# (442, 11)
# (430, 11)

# %%
# now again seprating input and output
df_x=df_combined_new.drop(columns=['DiseaseProgression'])
df_y=df_combined_new[["DiseaseProgression"]]

# %%
def maxr2_score(regr,df_x,df_y):
    max_r_score=0
    for r_state in range(42,100):
        x_train,x_test,y_train,y_test=train_test_split(df_x,df_y,random_state=r_state,test_size=0.20)
        
        regr.fit(x_train,y_train)
        y_pred=regr.predict(x_test)
        r2_scr=r2_score(y_test,y_pred)
        print("r2_score corrosponding to random state :",r_state," is: ",r2_scr)
        if r2_scr>max_r_score:
            max_r_score=r2_scr
            final_r_state=r_state

    print("max r2 score corrosponding to:",final_r_state," is ",max_r_score)
    return final_r_state

# %%
# lets use linear regression and check max r2_score to different random states
from sklearn.linear_model import LinearRegression
lreg=LinearRegression()
r_state=maxr2_score(lreg,df_x,df_y)
# Out:
# r2_score corrosponding to random state : 42  is:  0.3666696589544701
# r2_score corrosponding to random state : 43  is:  0.5414633719716159
# r2_score corrosponding to random state : 44  is:  0.502830202394811
# r2_score corrosponding to random state : 45  is:  0.41940208977825444
# r2_score corrosponding to random state : 46  is:  0.49944594921344987
# r2_score corrosponding to random state : 47  is:  0.5696168464053883
# r2_score corrosponding to random state : 48  is:  0.48941614789926113
# r2_score corrosponding to random state : 49  is:  0.4157614115642505
# r2_score corrosponding to random state : 50  is:  0.5113404267738513
# r2_score corrosponding to random state : 51  is:  0.25353904234282654
# r2_score corrosponding to random state : 52  is:  0.6129709896007236
# r2_score corrosponding to random state : 53  is:  0.41643342507750947
# r2_score corrosponding to random state : 54  is:  0.5374683464284008
# r2_score corrosponding to random state : 55  is:  0.48857235252489817
# r2_score corrosponding to random state : 56  is:  0.31394754546793013
# r2_score corrosponding to random state : 57  is:  0.3987795821170861
# r2_score corrosponding to random state : 58  is:  0.5386412864690377
# r2_score corrosponding to random state : 59  is:  0.4399904821531171
# r2_score corrosponding to random state : 60  is:  0.47232409291236543
# r2_score corrosponding to random state : 61  is:  0.603076673940736
# r2_score corrosponding to random state : 62  is:  0.32857273778439056
# r2_score corrosponding to random state : 63  is:  0.3709776124440525
# r2_score corrosponding to random state : 64  is:  0.4781873297146566
# r2_score corrosponding to random state : 65  is:  0.42403073307148265
# r2_score corrosponding to random state : 66  is:  0.34523135968037644
# r2_score corrosponding to random state : 67  is:  0.5211022173934445
# r2_score corrosponding to random state : 68  is:  0.4660328632026337
# r2_score corrosponding to random state : 69  is:  0.5993215324789298
# r2_score corrosponding to random state : 70  is:  0.5891081514574839
# r2_score corrosponding to random state : 71  is:  0.4725769890003353
# r2_score corrosponding to random state : 72  is:  0.465070394091211
# r2_score corrosponding to random state : 73  is:  0.4516693884290638
# r2_score corrosponding to random state : 74  is:  0.5042728258045484
# r2_score corrosponding to random state : 75  is:  0.47811967985500126
# r2_score corrosponding to random state : 76  is:  0.45568279714616433
# r2_score corrosponding to random state : 77  is:  0.5085873212683414
# r2_score corrosponding to random state : 78  is:  0.36407345814686276
# r2_score corrosponding to random state : 79  is:  0.3725541958099977
# r2_score corrosponding to random state : 80  is:  0.5236724939758377
# r2_score corrosponding to random state : 81  is:  0.4253354835748894
# r2_score corrosponding to random state : 82  is:  0.31840079720460923
# r2_score corrosponding to random state : 83  is:  0.39070077789759694
# r2_score corrosponding to random state : 84  is:  0.5327667583770852
# r2_score corrosponding to random state : 85  is:  0.4276220530690753
# r2_score corrosponding to random state : 86  is:  0.5115984646910832
# r2_score corrosponding to random state : 87  is:  0.4723584343817828
# r2_score corrosponding to random state : 88  is:  0.46325086683481786
# r2_score corrosponding to random state : 89  is:  0.4701807561449324
# r2_score corrosponding to random state : 90  is:  0.42789249433583443
# r2_score corrosponding to random state : 91  is:  0.5349020780910557
# r2_score corrosponding to random state : 92  is:  0.5351907235215829
# r2_score corrosponding to random state : 93  is:  0.43052728405482854
# r2_score corrosponding to random state : 94  is:  0.46589277598171586
# r2_score corrosponding to random state : 95  is:  0.4276807654980973
# r2_score corrosponding to random state : 96  is:  0.48252164426074473
# r2_score corrosponding to random state : 97  is:  0.5450125036671557
# r2_score corrosponding to random state : 98  is:  0.43828298121112075
# r2_score corrosponding to random state : 99  is:  0.626951653171429
# max r2 score corrosponding to: 99  is  0.626951653171429

# %%
# lets use grid search to find the optimal value of n neighbor for KNN model
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsRegressor
neighbors={'n_neighbors':range(1,30)}
knr=KNeighborsRegressor()
gsc=GridSearchCV(knr,neighbors,cv=10)
gsc.fit(df_x,df_y)
gsc.best_params_
# Out:
# {'n_neighbors': 19}

# %%
#lets use KNN regression and check max r2_score corrosponding different random state
knr=KNeighborsRegressor(n_neighbors=19)
r_state=maxr2_score(knr,df_x,df_y)
# Out:
# r2_score corrosponding to random state : 42  is:  0.3754639421781797
# r2_score corrosponding to random state : 43  is:  0.4850176749925311
# r2_score corrosponding to random state : 44  is:  0.5070124907462026
# r2_score corrosponding to random state : 45  is:  0.34696634001528726
# r2_score corrosponding to random state : 46  is:  0.451542905441379
# r2_score corrosponding to random state : 47  is:  0.4895196971602195
# r2_score corrosponding to random state : 48  is:  0.4958809239179024
# r2_score corrosponding to random state : 49  is:  0.42630690730410414
# r2_score corrosponding to random state : 50  is:  0.45313119612132746
# r2_score corrosponding to random state : 51  is:  0.2678001378172621
# r2_score corrosponding to random state : 52  is:  0.5358847489904657
# r2_score corrosponding to random state : 53  is:  0.4586727843601762
# r2_score corrosponding to random state : 54  is:  0.46474045120456287
# r2_score corrosponding to random state : 55  is:  0.41518128514327657
# r2_score corrosponding to random state : 56  is:  0.33146594793420947
# r2_score corrosponding to random state : 57  is:  0.41031633084078845
# r2_score corrosponding to random state : 58  is:  0.5402584419605948
# r2_score corrosponding to random state : 59  is:  0.42953599823241373
# r2_score corrosponding to random state : 60  is:  0.46738745945600657
# r2_score corrosponding to random state : 61  is:  0.5553079262704815
# r2_score corrosponding to random state : 62  is:  0.33066066702607766
# r2_score corrosponding to random state : 63  is:  0.3783895137967106
# r2_score corrosponding to random state : 64  is:  0.48421379326260394
# r2_score corrosponding to random state : 65  is:  0.44261746471618224
# r2_score corrosponding to random state : 66  is:  0.2698653959802415
# r2_score corrosponding to random state : 67  is:  0.36908453542069697
# r2_score corrosponding to random state : 68  is:  0.4394873343265039
# r2_score corrosponding to random state : 69  is:  0.5187953839385533
# r2_score corrosponding to random state : 70  is:  0.5208596450734551
# r2_score corrosponding to random state : 71  is:  0.4167489822309206
# r2_score corrosponding to random state : 72  is:  0.39331922475442993
# r2_score corrosponding to random state : 73  is:  0.43251087373979524
# r2_score corrosponding to random state : 74  is:  0.5170866920482625
# r2_score corrosponding to random state : 75  is:  0.4478426348533341
# r2_score corrosponding to random state : 76  is:  0.4339141161652411
# r2_score corrosponding to random state : 77  is:  0.41530671180657985
# r2_score corrosponding to random state : 78  is:  0.42243925700111273
# r2_score corrosponding to random state : 79  is:  0.3505917019162451
# r2_score corrosponding to random state : 80  is:  0.4245561118826796
# r2_score corrosponding to random state : 81  is:  0.34241234907433316
# r2_score corrosponding to random state : 82  is:  0.38038532749795073
# r2_score corrosponding to random state : 83  is:  0.397615256396471
# r2_score corrosponding to random state : 84  is:  0.4114107020200227
# r2_score corrosponding to random state : 85  is:  0.4874359343901714
# r2_score corrosponding to random state : 86  is:  0.471843473823647
# r2_score corrosponding to random state : 87  is:  0.475164354198919
# r2_score corrosponding to random state : 88  is:  0.37825637663616063
# r2_score corrosponding to random state : 89  is:  0.4121324563017762
# r2_score corrosponding to random state : 90  is:  0.43964228007857065
# r2_score corrosponding to random state : 91  is:  0.4851635167156674
# r2_score corrosponding to random state : 92  is:  0.4902993334212776
# r2_score corrosponding to random state : 93  is:  0.41204732125202204
# r2_score corrosponding to random state : 94  is:  0.447939845627653
# r2_score corrosponding to random state : 95  is:  0.372989497860159
# r2_score corrosponding to random state : 96  is:  0.4798458335710769
# r2_score corrosponding to random state : 97  is:  0.4558562085206812
# r2_score corrosponding to random state : 98  is:  0.4429255304005809
# r2_score corrosponding to random state : 99  is:  0.5372893665697835
# max r2 score corrosponding to: 61  is  0.5553079262704815

# %%
# lets check mean r2_score for KNN and linear regression
from sklearn.model_selection import cross_val_score
print('Mean r2_score for Linear Regression :',cross_val_score(lreg,df_x,df_y,cv=5,scoring='r2').mean())
print('Standard deviation  for Linear Regression :',cross_val_score(lreg,df_x,df_y,cv=5,scoring='r2').std())
print()
# Out:
# Mean r2_score for Linear Regression : 0.4676911221693185
# Standard deviation for Linear Regression : 0.05595217785841939

# %%
print('Mean r2_score for KNN :',cross_val_score(knr,df_x,df_y,cv=5,scoring='r2').mean())
print('Mean r2_score for KNN :',cross_val_score(knr,df_x,df_y,cv=5,scoring='r2').std())
# Out:
# Mean r2_score for KNN : 0.4447393304649888
# Mean r2_score for KNN : 0.06885364198445655

# %%
# lets check the lasso regression find the best value of alpha
from sklearn.linear_model import Lasso
lsreg=Lasso()
parameter={"alpha":[0.0001,0.001,0.01,0.1,1]}
lgsc=GridSearchCV(lsreg,parameter,cv=10)
lgsc.fit(df_x,df_y)
lgsc.best_params_
# Out:
# {'alpha': 0.1}

# %%
#lets check max r2_score when we use Lasso
lsreg=Lasso(alpha=0.1)
r_state=maxr2_score(lsreg,df_x,df_y)
# Out:
# r2_score corrosponding to random state : 42  is:  0.39559614133403775
# r2_score corrosponding to random state : 43  is:  0.5279704191720399
# r2_score corrosponding to random state : 44  is:  0.50503294565865
# r2_score corrosponding to random state : 45  is:  0.4036196797761409
# r2_score corrosponding to random state : 46  is:  0.5035821455123144
# r2_score corrosponding to random state : 47  is:  0.5557723339863485
# r2_score corrosponding to random state : 48  is:  0.4951902457271492
# r2_score corrosponding to random state : 49  is:  0.41898867700436127
# r2_score corrosponding to random state : 50  is:  0.4841336844871694
# r2_score corrosponding to random state : 51  is:  0.2705971586987356
# r2_score corrosponding to random state : 52  is:  0.5965279705889219
# r2_score corrosponding to random state : 53  is:  0.4227011451196119
# r2_score corrosponding to random state : 54  is:  0.514897039321015
# r2_score corrosponding to random state : 55  is:  0.4921979652112449
# r2_score corrosponding to random state : 56  is:  0.3249514143291744
# r2_score corrosponding to random state : 57  is:  0.41824855781541936
# r2_score corrosponding to random state : 58  is:  0.5438396084200854
# r2_score corrosponding to random state : 59  is:  0.44859182287998944
# r2_score corrosponding to random state : 60  is:  0.4998521969434333
# r2_score corrosponding to random state : 61  is:  0.5946436513155507
# r2_score corrosponding to random state : 62  is:  0.3292015646228238
# r2_score corrosponding to random state : 63  is:  0.366514810681454
# r2_score corrosponding to random state : 64  is:  0.4886841889561808
# r2_score corrosponding to random state : 65  is:  0.4243759279884286
# r2_score corrosponding to random state : 66  is:  0.3558024076403584
# r2_score corrosponding to random state : 67  is:  0.49659168019338973
# r2_score corrosponding to random state : 68  is:  0.4610847398975164
# r2_score corrosponding to random state : 69  is:  0.5728238404592398
# r2_score corrosponding to random state : 70  is:  0.5743121261219555
# r2_score corrosponding to random state : 71  is:  0.449548578170593
# r2_score corrosponding to random state : 72  is:  0.4629130249893435
# r2_score corrosponding to random state : 73  is:  0.46881687014165185
# r2_score corrosponding to random state : 74  is:  0.4959419828959617
# r2_score corrosponding to random state : 75  is:  0.4797666406182508
# r2_score corrosponding to random state : 76  is:  0.4554730925472029
# r2_score corrosponding to random state : 77  is:  0.4794757306005858
# r2_score corrosponding to random state : 78  is:  0.36964302184106534
# r2_score corrosponding to random state : 79  is:  0.37585626273279515
# r2_score corrosponding to random state : 80  is:  0.5104689802704394
# r2_score corrosponding to random state : 81  is:  0.4217938349296846
# r2_score corrosponding to random state : 82  is:  0.3899368754484932
# r2_score corrosponding to random state : 83  is:  0.40682839935367054
# r2_score corrosponding to random state : 84  is:  0.5065218361430214
# r2_score corrosponding to random state : 85  is:  0.44823689701050684
# r2_score corrosponding to random state : 86  is:  0.5100453740518435
# r2_score corrosponding to random state : 87  is:  0.4680572800564162
# r2_score corrosponding to random state : 88  is:  0.458121294826466
# r2_score corrosponding to random state : 89  is:  0.47086258108514245
# r2_score corrosponding to random state : 90  is:  0.4115773586895217
# r2_score corrosponding to random state : 91  is:  0.5272547222803922
# r2_score corrosponding to random state : 92  is:  0.5220636016263058
# r2_score corrosponding to random state : 93  is:  0.43594244047480246
# r2_score corrosponding to random state : 94  is:  0.4822746405544437
# r2_score corrosponding to random state : 95  is:  0.40475836442100754
# r2_score corrosponding to random state : 96  is:  0.4807202490141723
# r2_score corrosponding to random state : 97  is:  0.5373235191356918
# r2_score corrosponding to random state : 98  is:  0.4364630009575615
# r2_score corrosponding to random state : 99  is:  0.5997275247178083
# max r2 score corrosponding to: 99  is  0.5997275247178083

# %%
# lets use cross_val_score with lasso
print('Mean r2_score for lasso regression:',cross_val_score(lsreg,df_x,df_y,cv=5,scoring='r2').mean())
print('Std. deviation in r2_score for lasso regression :',cross_val_score(lsreg,df_x,df_y,cv=5,scoring='r2').std())
#based on below output i can say lasso performed just like Linear regression
# Out:
# Mean r2_score for lasso regression: 0.4668358456202258
# Std. deviation in r2_score for lasso regression : 0.05024883603439513

# %%
# now try to boost the result using gradient boosting technique
# for getting best set of parameter we will use grid search
from sklearn.ensemble import GradientBoostingRegressor
gbr=GradientBoostingRegressor()
parameters={'learning_rate':[0.001,0.01,0.1,1],'n_estimators':[10,100,500,1000]}
clf=GridSearchCV(gbr,parameters,cv=5)
clf.fit(df_x,df_y)
clf.best_params_
# Out:
# {'learning_rate': 0.01, 'n_estimators': 500}

# %%
# now we will use cross_val_score to check the mean r2 score and standard deviation
gbr=GradientBoostingRegressor(learning_rate=0.01,n_estimators=500)
print('Mean r2_score for gradient boosting regression:',cross_val_score(gbr,df_x,df_y,cv=5,scoring='r2').mean())
print('Std. deviation in r2_score for gradient boosting regression :',cross_val_score(gbr,df_x,df_y,cv=5,scoring='r2').std())
# Out:
# Mean r2_score for gradient boosting regression: 0.4087664974730674
# Std. deviation in r2_score for gradient boosting regression : 0.07535985977794878

# %%
#now lets use AdaBoost Regression algorithm
from sklearn.ensemble import AdaBoostRegressor
from sklearn.tree import DecisionTreeRegressor
ada_reg=AdaBoostRegressor()
parameters={'learning_rate':[0.001,0.01,0.1,1],'n_estimators':[10,100,500,1000],'base_estimator':[lreg,lsreg,DecisionTreeRegressor()]}
clf1=GridSearchCV(ada_reg,parameters,cv=5)
clf1.fit(df_x,df_y)
clf1.best_params_
# Out:
# {'base_estimator': Lasso(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=1000,
#        normalize=False, positive=False, precompute=False, random_state=None,
#        selection='cyclic', tol=0.0001, warm_start=False),
#  'learning_rate': 0.001,
#  'n_estimators': 10}

# %%
ada_reg=AdaBoostRegressor(base_estimator=lsreg,learning_rate=0.001,n_estimators=10)
print('Mean r2_score for Ada boosting regression:',cross_val_score(ada_reg,df_x,df_y,cv=5,scoring='r2').mean())
print('Std. deviation in r2_score for Ada boosting regression :',cross_val_score(ada_reg,df_x,df_y,cv=5,scoring='r2').std())
# Out:
# Mean r2_score for Ada boosting regression: 0.46626601160322617
# Std. deviation in r2_score for Ada boosting regression : 0.051101306359568985

# %%
# lets check maximum r2_score corresponding to this 
r_state=maxr2_score(ada_reg,df_x,df_y)
# Out:
# r2_score corrosponding to random state : 42  is:  0.3935442373118436
# r2_score corrosponding to random state : 43  is:  0.5226269199319575
# r2_score corrosponding to random state : 44  is:  0.4965225409076255
# r2_score corrosponding to random state : 45  is:  0.39763305500819424
# r2_score corrosponding to random state : 46  is:  0.49970891131838324
# r2_score corrosponding to random state : 47  is:  0.5667103267251337
# r2_score corrosponding to random state : 48  is:  0.4933377610816234
# r2_score corrosponding to random state : 49  is:  0.4182429167577235
# r2_score corrosponding to random state : 50  is:  0.4796276583872824
# r2_score corrosponding to random state : 51  is:  0.2567198997338441
# r2_score corrosponding to random state : 52  is:  0.605477999490541
# r2_score corrosponding to random state : 53  is:  0.42671427701471965
# r2_score corrosponding to random state : 54  is:  0.524443741016313
# r2_score corrosponding to random state : 55  is:  0.48378568848001247
# r2_score corrosponding to random state : 56  is:  0.30314688188483196
# r2_score corrosponding to random state : 57  is:  0.4171902787109084
# r2_score corrosponding to random state : 58  is:  0.5380296684541657
# r2_score corrosponding to random state : 59  is:  0.4465345242853067
# r2_score corrosponding to random state : 60  is:  0.5025343862608451
# r2_score corrosponding to random state : 61  is:  0.595122365061603
# r2_score corrosponding to random state : 62  is:  0.32499617740437325
# r2_score corrosponding to random state : 63  is:  0.3555483422076341
# r2_score corrosponding to random state : 64  is:  0.48616438568886533
# r2_score corrosponding to random state : 65  is:  0.43800963955794026
# r2_score corrosponding to random state : 66  is:  0.3526306672161763
# r2_score corrosponding to random state : 67  is:  0.47860671527531784
# r2_score corrosponding to random state : 68  is:  0.47830855200563815
# r2_score corrosponding to random state : 69  is:  0.5609612339187028
# r2_score corrosponding to random state : 70  is:  0.5589060884386392
# r2_score corrosponding to random state : 71  is:  0.4597108568120464
# r2_score corrosponding to random state : 72  is:  0.45997452459349464
# r2_score corrosponding to random state : 73  is:  0.47374262030981784
# r2_score corrosponding to random state : 74  is:  0.47979854300346936
# r2_score corrosponding to random state : 75  is:  0.48534716426124236
# r2_score corrosponding to random state : 76  is:  0.4591764894604071
# r2_score corrosponding to random state : 77  is:  0.4860734348167437
# r2_score corrosponding to random state : 78  is:  0.37128975734557945
# r2_score corrosponding to random state : 79  is:  0.37979265547329044
# r2_score corrosponding to random state : 80  is:  0.5084791288168304
# r2_score corrosponding to random state : 81  is:  0.4136435445888572
# r2_score corrosponding to random state : 82  is:  0.38414955833337305
# r2_score corrosponding to random state : 83  is:  0.40523554218232427
# r2_score corrosponding to random state : 84  is:  0.49904462095817215
# r2_score corrosponding to random state : 85  is:  0.44646111513238873
# r2_score corrosponding to random state : 86  is:  0.5107325279682413
# r2_score corrosponding to random state : 87  is:  0.46817439718457354
# r2_score corrosponding to random state : 88  is:  0.4540171193046595
# r2_score corrosponding to random state : 89  is:  0.4693453879015814
# r2_score corrosponding to random state : 90  is:  0.402385530435857
# r2_score corrosponding to random state : 91  is:  0.5250000444815222
# r2_score corrosponding to random state : 92  is:  0.5231593709620119
# r2_score corrosponding to random state : 93  is:  0.42740495143887913
# r2_score corrosponding to random state : 94  is:  0.4821861055452218
# r2_score corrosponding to random state : 95  is:  0.40801122029724424
# r2_score corrosponding to random state : 96  is:  0.4704890561544073
# r2_score corrosponding to random state : 97  is:  0.5236674965320766
# r2_score corrosponding to random state : 98  is:  0.4345736125031533
# r2_score corrosponding to random state : 99  is:  0.5988729031348357
# max r2 score corrosponding to: 52  is  0.605477999490541

# %%
# we tried all the models and till now linear regression is best
#random state corrosponding to highest r2_score is 99
x_train,x_test,y_train,y_test=train_test_split(df_x,df_y,random_state=99,test_size=0.20)
lreg=LinearRegression()
lreg.fit(x_train,y_train)
y_pred=lreg.predict(x_test)

# %%
#find rmse and r2_score using sklearn.metrics
import numpy as np
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
print('RMSE is :',np.sqrt(mean_squared_error(y_test,y_pred)))
print('r2_score is :',r2_score(y_test,y_pred))
# Out:
# RMSE is : 48.95593018443329
# r2_score is : 0.626951653171429

# %%
from sklearn.externals import joblib
#save file as pickle
joblib.dump(lreg,'diabetes.pkl')
# Out:
# ['diabetes.pkl']
